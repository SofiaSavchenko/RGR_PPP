# %%
import pandas as pd

df = pd.read_csv('bestsellers with categories.csv')
df
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %%
import pandas as pd

df.head()
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
#
#                      Author  User Rating  Reviews  Price  Year        Genre
# 0                  JJ Smith          4.7    17350      8  2016  Non Fiction
# 1              Stephen King          4.6     2052     22  2011      Fiction
# 2        Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3             George Orwell          4.7    21424      6  2017      Fiction
# 4  National Geographic Kids          4.8     7665     12  2019  Non Fiction

# %%
import pandas as pd

df.tail()
# Out:
#                                                   Name       Author  \
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)  Jeff Kinney
# 546  You Are a Badass: How to Stop Doubting Your Gr...  Jen Sincero
# 547  You Are a Badass: How to Stop Doubting Your Gr...  Jen Sincero
# 548  You Are a Badass: How to Stop Doubting Your Gr...  Jen Sincero
# 549  You Are a Badass: How to Stop Doubting Your Gr...  Jen Sincero
#
#      User Rating  Reviews  Price  Year        Genre
# 545          4.9     9413      8  2019      Fiction
# 546          4.7    14331      8  2016  Non Fiction
# 547          4.7    14331      8  2017  Non Fiction
# 548          4.7    14331      8  2018  Non Fiction
# 549          4.7    14331      8  2019  Non Fiction

# %%
import pandas as pd

df.dtypes
# Out:
# Name            object
# Author          object
# User Rating    float64
# Reviews          int64
# Price            int64
# Year             int64
# Genre           object
# dtype: object

# %%
import pandas as pd

df.describe()
# Out:
#        User Rating       Reviews       Price         Year
# count   550.000000    550.000000  550.000000   550.000000
# mean      4.618364  11953.281818   13.100000  2014.000000
# std       0.226980  11731.132017   10.842262     3.165156
# min       3.300000     37.000000    0.000000  2009.000000
# 25%       4.500000   4058.000000    7.000000  2011.000000
# 50%       4.700000   8580.000000   11.000000  2014.000000
# 75%       4.800000  17253.250000   16.000000  2017.000000
# max       4.900000  87841.000000  105.000000  2019.000000

# %%
import pandas as pd

df = df.drop_duplicates()
df
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %%
import pandas as pd

df.rename(columns={'User Rating': 'Rating'}, inplace=True)
df
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith     4.7    17350      8  2016  Non Fiction
# 1                Stephen King     4.6     2052     22  2011      Fiction
# 2          Jordan B. Peterson     4.7    18979     15  2018  Non Fiction
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

df.hist(column='Rating')
plt.savefig('a.png')

# %%
import pandas as pd

df.boxplot(column='Price')
plt.savefig('b.png')

# %%
import matplotlib.pyplot as plt


df.groupby(['Genre']).size().plot(kind='pie', autopct='%.2f%%', figsize=(8,5))
plt.ylabel("")
plt.savefig('c.png')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize = (8,5))
sns.heatmap(df.corr(), annot = True, fmt='.1g')
plt.savefig('d.png')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

mass_author = []
mass_genre = []

for i, j in zip(df["Author"], df["Genre"]):
  if df["Author"].value_counts()[i] >= 5:
    mass_author.append(i)
    mass_genre.append(j)

data_new = list(zip(mass_author, mass_genre))

df_new = pd.DataFrame(data_new, columns=['Author', 'Genre'])
df_new

plt.figure(figsize = (8,8))

sns.countplot(x='Genre', hue='Author', data=df_new)
plt.savefig('e.png')

# %%
import pandas as pd

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 550 entries, 0 to 549
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Name     550 non-null    object
#  1   Author   550 non-null    object
#  2   Rating   550 non-null    float64
#  3   Reviews  550 non-null    int64
#  4   Price    550 non-null    int64
#  5   Year     550 non-null    int64
#  6   Genre    550 non-null    object
# dtypes: float64(1), int64(3), object(3)
# memory usage: 34.4+ KB

# %%
import pandas as pd

df.isna().sum()
# Out:
# Name       0
# Author     0
# Rating     0
# Reviews    0
# Price      0
# Year       0
# Genre      0
# dtype: int64

# %%
import pandas as pd
from scipy import stats

df_character = df['Price'][:200]
alpha = 1e-3

a, b = stats.normaltest(df_character)
if b < alpha: 
  print("The hypothesis can be rejected")
else:
  print("The hypothesis cannot be rejected")
# Out:
# The hypothesis can be rejected

# %%
import pandas as pd

one_hot_encoded = pd.get_dummies(columns=['Genre'], data = df)
one_hot_encoded
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  Rating  Reviews  Price  Year  Genre_Fiction  \
# 0                    JJ Smith     4.7    17350      8  2016              0
# 1                Stephen King     4.6     2052     22  2011              1
# 2          Jordan B. Peterson     4.7    18979     15  2018              0
# ...

# %%
import pandas as pd

df.to_csv('file.csv')
